# %% [markdown]
# ### 0. Dice rolls (*)
# - Simulate 10 dice rolls and append the rolls to a list or use list comprehension.
#
#   - a)   sort the list in ascending order (*)

# %%
import random

roll_dics = [random.randint(1,6) for i in range(10)]

roll_dics_accending = sorted(roll_dics )

print(roll_dics)
print(roll_dics_accending)
# Out:
# [5, 2, 6, 5, 2, 3, 6, 2, 3, 1]
# [6, 6, 5, 5, 3, 3, 2, 2, 2, 1]

# %% [markdown]
# - b)   sort the list in descending order (*)

# %%
import random

roll_dics = [random.randint(1,6) for i in range(10)]

roll_dics_descending = sorted(roll_dics , reverse=True)

print(roll_dics)
print(roll_dics_descending)
# Out:
# [3, 2, 4, 1, 5, 1, 3, 4, 6, 5]
# [6, 5, 5, 4, 4, 3, 3, 2, 1, 1]

# %%
import random

roll_dics = [random.randint(1,6) for i in range(10)]

min_num = min(roll_dics)
max_num = max(roll_dics)

print(roll_dics)
print(f"Min number {min_num}")
print(f"max number {max_num}")
# Out:
# [4, 1, 4, 1, 2, 5, 4, 6, 1, 3]
# Min number 1
# max number 6

# %% [markdown]
# ### 1. Food menu (*)
# - Create a:
#
#   - a)   list with the following elements: "vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor". (*)

# %%
veg_name = ["vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor"]

for i , veg in enumerate(veg_name , 1):
    print(f" {i} : {veg}")
# Out:
#  1 : vegetarisk lasagne
#  2 : spaghetti
#  3 : fisk
#  4 : grönsakssoppa
#  5 : pannkakor

# %% [markdown]
#  - b)   list with the weekdays (*)

# %%
week_days = ["Monday", "Tuesday","Wwdnesday", "Thursday", "Friday", "Saturday", "sunday"]

for i , days in enumerate(week_days , 1):

    print(f" {i} : {days}")
# Out:
#  1 : Monday
#  2 : Tuesday
#  3 : Wwdnesday
#  4 : Thursday
#  5 : Friday
#  6 : Saturday
#  7 : sunday

# %% [markdown]
# - c)   create a food menu with each day corresponding to each food item and print it out. (*)

# %%
week_days = ["Monday", "Tuesday","Wwdnesday", "Thursday", "Friday", "Saturday", "sunday"]

veg_name = ["vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor", "potato"]


for day , name in zip(week_days , veg_name):
    print(f" {day} : {veg}")
# Out:
#  Monday : pannkakor
#  Tuesday : pannkakor
#  Wwdnesday : pannkakor
#  Thursday : pannkakor
#  Friday : pannkakor
#  Saturday : pannkakor

# %% [markdown]
# 2. Squares (*)
#   - a)   Use list comprehension to create a list of squares from -10 to 10 (*)
#
#   - b)   Plot this list using matplotlib. (*)

# %%
sqr= [x**2 for x in range (-10,11)]
print(sqr)
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
import matplotlib.pyplot as plt

sqr= [x**2 for x in range (-10,11)]

plt.plot(range(-10,11),sqr , label = "square of X")

plt.xlabel("x")
plt.ylabel("y")
plt.title("square of X")

plt.legend()
plt.show()

# %% [markdown]
# ### 3. Chessboard (**)
#   - a)   Create this list using list comprehension: (*)
#
# - ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
#   - b)   Create a 2D list to hold the coordinates in a chessboard. (**)

# %%
alfabet = ["A" , "B" , "C" , "D" , "E" , "F" , "G", "H"]

for i, alf in enumerate(alfabet , 1):
    print(f"{alf}1", end=" ")
# Out:
# A1 B1 C1 D1 E1 F1 G1 H1

# %% [markdown]
# ## 4. Dice rolls convergence (**)
# Simulate:
#
#   - a)   100 dice rolls and count the number of outcome six. (*)

# %%
import random 

num_six = 0
roll_dics = 100

for i in range(roll_dics):
    dics = random.randint(1,6)
    if dics ==6:
        num_six +=1

print(f"the number of six is {num_six} in {roll_dics} ")
# Out:
# the number of six is 22 in 100

# %% [markdown]
# - b)   10, 100, 1000, 10000, 100000, 1000000 dice rolls. Count the number of outcome six in each simulation and store it in a list. Compute the probability of outcome six in each simulation. (**)

# %%
import random
num_six = 0
roll_dice = [10,100,1000,10000,100000,1000000]
num_six_list = []

for i in range(len(roll_dice)):
    for _ in range(roll_dice[i]):
        dice_ = random.randint(1,6)
        if dice_ == 6:
            num_six += 1
    num_six_list.append(num_six)

print(num_six_list)
# Out:
# [2, 24, 176, 1885, 18732, 184841]

# %% [markdown]
# - c)   Use matplotlib to plot this list. (*)

# %%
import matplotlib.pyplot as plt


plt.plot(roll_dice,num_six_list , marker= 'o')
plt.xlabel('Number of Rolls')
plt.ylabel('Number of sixes')
plt.title('Number of sixes vs Number of Rolls')
plt.grid(True)
plt.show()
